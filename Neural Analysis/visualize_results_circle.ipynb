# %%
import evaluation as eva

# %%
# Example usage - visualize MAE
filepath = "./simulation_results/sim_res_O_SIREN_5_0.json"
eva.visualize_results(filepath, metric='MAE', log_scale=True, plot_num_of_elements=False)
# Out:
# Results from: ./simulation_results/sim_res_O_SIREN_5_0.json
# Timestamp: 2026-01-11T17:51:31.203671
#
# MAE values:
# --------------------------------------------------
#
# Order p = 1:
#   div= 10 (h=0.0909): 9.387526e-04
#   div= 20 (h=0.0476): 2.807079e-04
#   div= 50 (h=0.0196): 4.987829e-05
#   div= 80 (h=0.0123): 2.115935e-05
#   div=100 (h=0.0099): 1.427584e-05
#   div=150 (h=0.0066): 7.593076e-06
#
# Order p = 2:
#   div= 10 (h=0.0909): 1.322766e-04
#   div= 20 (h=0.0476): 2.866160e-05
#   div= 50 (h=0.0196): 7.062460e-06
#   div= 80 (h=0.0123): 4.686989e-06
#   div=100 (h=0.0099): 4.115043e-06
#   div=150 (h=0.0066): 3.553869e-06
#
# Order p = 3:
#   div= 10 (h=0.0909): 4.757996e-05
#   div= 20 (h=0.0476): 1.179060e-05
#   div= 50 (h=0.0196): 6.551059e-06
#   div= 80 (h=0.0123): 3.747693e-06
#   div=100 (h=0.0099): 3.309888e-06
#   div=150 (h=0.0066): 3.401745e-06

# %%
# Example usage - visualize MAE
filepath = "./simulation_results/simulation_results_AnalyticalDistanceCircleWEB_20260125_170634.json"
eva.visualize_results(filepath, metric='MAE', log_scale=True)
# Out:
# Results from: ./simulation_results/simulation_results_AnalyticalDistanceCircleWEB_20260125_170634.json
# Timestamp: 2026-01-25T17:06:34.500078
#
# MAE values:
# --------------------------------------------------
#
# Order p = 1:
#   div= 10 (h=0.0909): 3.459641e-02
#   div= 20 (h=0.0476): 1.897913e-02
#   div= 50 (h=0.0196): 5.716747e-03
#   div= 80 (h=0.0123): 3.685802e-03
#   div=100 (h=0.0099): 2.922118e-03
#   div=120 (h=0.0083): 2.078188e-03
#
# Order p = 2:
#   div= 10 (h=0.0909): 8.891885e-03
#   div= 20 (h=0.0476): 3.454844e-03
#   div= 50 (h=0.0196): 6.572746e-04
#   div= 80 (h=0.0123): 2.371331e-04
#   div=100 (h=0.0099): 1.426781e-04
#   div=120 (h=0.0083): 8.766603e-05
#
# Order p = 3:
#   div= 10 (h=0.0909): 6.769061e-03
#   div= 20 (h=0.0476): 1.643854e-03
#   div= 50 (h=0.0196): 2.438844e-04
#   div= 80 (h=0.0123): 6.335925e-05
#   div=100 (h=0.0099): 2.875606e-05
#   div=120 (h=0.0083): 1.398800e-05

# %%
# Example usage - visualize MAE
filepath = "./simulation_results/sim_res_O_analytic.json"
eva.visualize_results(filepath, metric='MAE', log_scale=True)
# Out:
# Results from: ./simulation_results/sim_res_O_analytic.json
# Timestamp: 2026-01-11T18:57:13.494035
#
# MAE values:
# --------------------------------------------------
#
# Order p = 1:
#   div= 10 (h=0.0909): 9.402673e-04
#   div= 20 (h=0.0476): 2.775709e-04
#   div= 50 (h=0.0196): 4.614307e-05
#   div= 80 (h=0.0123): 1.884617e-05
#   div= 95 (h=0.0104): 1.396532e-05
#   div=100 (h=0.0099): 1.210775e-05
#   div=105 (h=0.0094): 1.153580e-05
#   div=120 (h=0.0083): 8.927176e-06
#   div=150 (h=0.0066): 5.589245e-06
#   div=200 (h=0.0050): 3.004373e-06
#
# Order p = 2:
#   div= 10 (h=0.0909): 1.309321e-04
#   div= 20 (h=0.0476): 2.286577e-05
#   div= 50 (h=0.0196): 4.096645e-06
#   div= 80 (h=0.0123): 1.023175e-06
#   div= 95 (h=0.0104): 1.418265e-06
#   div=100 (h=0.0099): 1.537327e-06
#   div=105 (h=0.0094): 1.335795e-06
#   div=120 (h=0.0083): 8.452595e-07
#   div=150 (h=0.0066): 5.417919e-07
#   div=200 (h=0.0050): 4.130653e-07
#
# Order p = 3:
#   div= 10 (h=0.0909): 4.699986e-05
# ...

# %%
filepath = "./simulation_results/sim_res_O_SIREN_1_2.json"
eva.visualize_results(filepath, metric='MAE', log_scale=True, plot_num_of_elements=False)
# Out:
# Results from: ./simulation_results/sim_res_O_SIREN_1_2.json
# Timestamp: 2026-01-11T20:54:02.779356
#
# MAE values:
# --------------------------------------------------
#
# Order p = 1:
#   div= 10 (h=0.0909): 9.408483e-04
#   div= 20 (h=0.0476): 2.874459e-04
#   div= 50 (h=0.0196): 5.659528e-05
#   div= 80 (h=0.0123): 3.164773e-05
#   div=100 (h=0.0099): 2.795754e-05
#   div=150 (h=0.0066): 2.587494e-05
#
# Order p = 2:
#   div= 10 (h=0.0909): 1.740590e-04
#   div= 20 (h=0.0476): 6.946086e-05
#   div= 50 (h=0.0196): 2.536430e-05
#   div= 80 (h=0.0123): 2.493359e-05
#   div=100 (h=0.0099): 2.463507e-05
#   div=150 (h=0.0066): 2.518823e-05
#
# Order p = 3:
#   div= 10 (h=0.0909): 9.536394e-05
#   div= 20 (h=0.0476): 6.286124e-05
#   div= 50 (h=0.0196): 2.533884e-05
#   div= 80 (h=0.0123): 2.449993e-05
#   div=100 (h=0.0099): 2.513881e-05
#   div=150 (h=0.0066): 2.502054e-05

# %%
filepath = "./simulation_results/simulation_results_AnalyticalDistanceCircleTanh_20260113_225601.json"
eva.visualize_results(filepath, metric='MAE', log_scale=True, plot_num_of_elements=False)
# Out:
# Results from: ./simulation_results/simulation_results_AnalyticalDistanceCircleTanh_20260113_225601.json
# Timestamp: 2026-01-13T22:56:01.529679
#
# MAE values:
# --------------------------------------------------
#
# Order p = 1:
#   div= 10 (h=0.0909): 5.674900e-04
#   div= 20 (h=0.0476): 1.674077e-04
#   div= 50 (h=0.0196): 2.803680e-05
#   div= 80 (h=0.0123): 1.143318e-05
#   div=100 (h=0.0099): 7.780887e-06
#
# Order p = 2:
#   div= 10 (h=0.0909): 8.431093e-05
#   div= 20 (h=0.0476): 1.749959e-05
#   div= 50 (h=0.0196): 3.939839e-06
#   div= 80 (h=0.0123): 9.671223e-07
#   div=100 (h=0.0099): 1.522339e-06
#
# Order p = 3:
#   div= 10 (h=0.0909): 3.209932e-05
#   div= 20 (h=0.0476): 6.063755e-06
#   div= 50 (h=0.0196): 1.097866e-06
#   div= 80 (h=0.0123): 9.787357e-07
#   div=100 (h=0.0099): 2.109416e-06

# %%
filepath = "./simulation_results/simulation_results_ReLU_circle_4_0_20260114_175340.json"
eva.visualize_results(filepath, metric='MAE', log_scale=True, plot_num_of_elements=False)
# Out:
# Results from: ./simulation_results/simulation_results_ReLU_circle_4_0_20260114_175340.json
# Timestamp: 2026-01-14T17:53:40.624998
#
# MAE values:
# --------------------------------------------------
#
# Order p = 1:
#   div= 10 (h=0.0909): 9.745780e-04
#   div= 20 (h=0.0476): 3.388121e-04
#   div= 50 (h=0.0196): 1.089261e-04
#   div= 80 (h=0.0123): 9.072008e-05
#   div=100 (h=0.0099): 5.908197e-05
#
# Order p = 2:
#   div= 10 (h=0.0909): 3.219558e-04
#   div= 20 (h=0.0476): 1.706530e-04
#   div= 50 (h=0.0196): 8.949885e-05
#   div= 80 (h=0.0123): 8.745021e-05
#   div=100 (h=0.0099): 5.672300e-05
#
# Order p = 3:
#   div= 10 (h=0.0909): 2.118085e-04
#   div= 20 (h=0.0476): 1.371262e-04
#   div= 50 (h=0.0196): 7.568251e-05
#   div= 80 (h=0.0123): 5.776387e-05
#   div=100 (h=0.0099): 6.262955e-05

# %%
filepath = "./simulation_results/simulation_results_AnalyticalDistanceCircle_smart_WEB_20260125_201645.json"
eva.visualize_results(filepath, metric='MAE', log_scale=True, plot_num_of_elements=False)
# Out:
# Results from: ./simulation_results/simulation_results_AnalyticalDistanceCircle_smart_WEB_20260125_201645.json
# Timestamp: 2026-01-25T20:16:45.835268
#
# MAE values:
# --------------------------------------------------
#
# Order p = 1:
#   div= 10 (h=0.0909): 9.402673e-04
#   div= 20 (h=0.0476): 2.775709e-04
#   div= 50 (h=0.0196): 4.618167e-05
#   div= 80 (h=0.0123): 1.885248e-05
#   div=100 (h=0.0099): 1.210124e-05
#   div=120 (h=0.0083): 8.950903e-06
#
# Order p = 2:
#   div= 10 (h=0.0909): 1.307592e-04
#   div= 20 (h=0.0476): 2.315483e-05
#   div= 50 (h=0.0196): 3.524942e-06
#   div= 80 (h=0.0123): 1.050557e-06
#   div=100 (h=0.0099): 1.336781e-06
#   div=120 (h=0.0083): 1.026736e-06
#
# Order p = 3:
#   div= 10 (h=0.0909): 4.732112e-05
#   div= 20 (h=0.0476): 7.235388e-06
#   div= 50 (h=0.0196): 1.402645e-06
#   div= 80 (h=0.0123): 1.066638e-06
#   div=100 (h=0.0099): 1.924486e-06
#   div=120 (h=0.0083): 2.763289e-07

# %%
# Compare multiple simulation files
filepaths = [
    "simulation_results\\sim_res_O_SIREN_5_0.json",
    "simulation_results\\sim_res_O_analytic.json",
    "simulation_results\\sim_res_O_SIREN_1_2.json",
    "simulation_results\\simulation_results_AnalyticalDistanceCircleTanh_20260113_225601.json",
    "simulation_results\\simulation_results_ReLU_circle_4_0_20260114_175340.json",
    "simulation_results\\simulation_results_AnalyticalDistanceCircleWEB_20260125_170634.json",
    "simulation_results\\simulation_results_AnalyticalDistanceCircle_smart_WEB_20260125_201645.json"

]

# Show orders 1 and 2 for all files
eva.compare_simulations(
    filepaths=filepaths,
    orders_to_show=[3],
    metric='MAE',
    log_scale=True,
    labels=['SIREN 5.0', 'Analytical', 'SIREN 1.2', 'Analytical Tanh', 'ReLU 4.0', 'WEB-Splines', 'smart_web']  # Optional custom labels
)
# Out:
# ...
# Comparison Summary - Metric: MAE
# ...
#
# SIREN 5.0:
# --------------------------------------------------
#   Order p = 3:
#     div= 10 (h=0.0909): 4.757996e-05
#     div= 20 (h=0.0476): 1.179060e-05
#     div= 50 (h=0.0196): 6.551059e-06
#     div= 80 (h=0.0123): 3.747693e-06
#     div=100 (h=0.0099): 3.309888e-06
#     div=150 (h=0.0066): 3.401745e-06
#
# Analytical:
# --------------------------------------------------
#   Order p = 3:
#     div= 10 (h=0.0909): 4.699986e-05
#     div= 20 (h=0.0476): 7.348872e-06
#     div= 50 (h=0.0196): 1.151338e-06
#     div= 80 (h=0.0123): 9.865633e-07
#     div= 95 (h=0.0104): 7.498259e-07
#     div=100 (h=0.0099): 2.111724e-06
#     div=105 (h=0.0094): 1.048783e-06
#     div=120 (h=0.0083): 4.043721e-07
#     div=150 (h=0.0066): 1.979407e-07
#     div=200 (h=0.0050): 3.538329e-07
#
# SIREN 1.2:
# --------------------------------------------------
#   Order p = 3:
#     div= 10 (h=0.0909): 9.536394e-05
#     div= 20 (h=0.0476): 6.286124e-05
# ...
