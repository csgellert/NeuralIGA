# %%
import collocation_WEB as cWEB
import numpy as np
import matplotlib.pyplot as plt
import importlib
import Geomertry
import mesh

# %% [markdown]
# # New - enchancing WEB

# %%
importlib.reload(cWEB)
importlib.reload(mesh)
# Weight function - using analytical circle distance in [-1,1]² domain
#model = Geomertry.AnaliticalDistanceCircle()
#model = Geomertry.AnaliticalDistanceLshape_RFunction()
#model  = Geomertry.AnaliticalDistanceLshape()
#model = load_test_model("SIREN_L_3_0", "SIREN", params={"architecture": [2, 256, 256, 256, 1], "w_0": 80, "w_hidden": 120.0})
#model = Geomertry.AnaliticalDistanceLshape_RFunction()
model = Geomertry.AnaliticalDistance_CASE8()
res = cWEB.run_example(model=model, n=4, H=100, function_case=8, verbose=True, plot_mode='2d')
# Out:
# ============================================================
# WEB-Spline Collocation: degree=4, H=100, domain={'x1': -4.0, 'x2': 4.0, 'y1': -3.0, 'y2': 3.0}, case=8
# ============================================================
# Domain transform: [0,1]² → [-4.0,4.0]×[-3.0,3.0]
# Laplacian factors in grid coords: ax=1/scale_x^2=1.562e-02, ay=1/scale_y^2=2.778e-02
# Classification...
#   Inner B-splines: 7204
#   Outer B-splines: 1032
#   Inner element arrays: 6172
# Building extension matrix...
#   Extension matrix: 7204 x 1032, nnz = 10300
# Assembling collocation matrix...
# line 1081 -> fiy this later!!!
# Solving linear system...
#   System dimension: 7204
#   Condition number: N/A (system too large)
# Evaluating solution...
#
# ========================================
# Results:
# ========================================
#   Relative max error: 4.555033e-05
#   Relative L2 error:  1.281296e-05
#   Mean absolute error: 5.365750e-06
#   Absolute L-inf error: 4.555031e-05
#   H1 semi-norm error: 1.808435e-01
#   H1 error:           1.808435e-01
#   Condition number:   N/A
#   System dimension:   7204
#
# Timing:
#   Classification/Assembly: 0.150s
#   Extension:               0.086s
#   Solution:                0.191s
#   Total:                   0.426s

# %% [markdown]
# # Palying around

# %%
importlib.reload(cWEB)
# Weight function - using analytical circle distance in [-1,1]² domain
model = Geomertry.AnaliticalDistanceCircle()
#model  = Geomertry.AnaliticalDistanceLshape()
#model = load_test_model("SIREN_L_3_0", "SIREN", params={"architecture": [2, 256, 256, 256, 1], "w_0": 80, "w_hidden": 120.0})
#model = Geomertry.AnaliticalDistanceLshape_RFunction()
res = cWEB.run_example(model=model, n=2, H=100, function_case=1, verbose=True)
# Out:
# ============================================================
# WEB-Spline Collocation: degree=2, H=100, domain={'x1': -1.0, 'x2': 1.0, 'y1': -1.0, 'y2': 1.0}, case=1
# ============================================================
# Domain transform: [0,1]² → [-1.0,1.0]×[-1.0,1.0]
# Laplacian factors in grid coords: ax=1/scale_x^2=2.500e-01, ay=1/scale_y^2=2.500e-01
# Classification...
#   Inner B-splines: 7860
#   Outer B-splines: 404
#   Inner element arrays: 7464
# Building extension matrix...
#   Extension matrix: 7860 x 404, nnz = 1932
# Assembling collocation matrix...
# line 1081 -> fiy this later!!!
# Solving linear system...
#   System dimension: 7860
#   Condition number: N/A (system too large)
# Evaluating solution...
#
# ========================================
# Results:
# ========================================
#   Relative max error: 7.481326e-05
#   Relative L2 error:  3.695364e-05
#   Mean absolute error: 5.260339e-06
#   Absolute L-inf error: 2.878440e-05
#   H1 semi-norm error: 9.537337e-02
#   H1 error:           9.537337e-02
#   Condition number:   N/A
#   System dimension:   7860
#
# Timing:
#   Classification/Assembly: 0.100s
#   Extension:               0.028s
#   Solution:                0.053s
#   Total:                   0.181s

# %%
importlib.reload(cWEB)
# Weight function - using analytical circle distance in [-1,1]² domain
#model = Geomertry.AnaliticalDistanceCircle()
model = Geomertry.AnaliticalDistanceCircle_smooth()
#model  = Geomertry.AnaliticalDistanceLshape()
#model = load_test_model("SIREN_L_3_0", "SIREN", params={"architecture": [2, 256, 256, 256, 1], "w_0": 80, "w_hidden": 120.0})
#model = Geomertry.AnaliticalDistanceLshape_RFunction()
res = cWEB.run_example(model=model, n=2, H=100, function_case=1, verbose=True)
# Out:
# ============================================================
# WEB-Spline Collocation: degree=2, H=100, domain={'x1': -1.0, 'x2': 1.0, 'y1': -1.0, 'y2': 1.0}, case=1
# ============================================================
# Domain transform: [0,1]² → [-1.0,1.0]×[-1.0,1.0]
# Laplacian factors in grid coords: ax=1/scale_x^2=2.500e-01, ay=1/scale_y^2=2.500e-01
# Classification...
#   Inner B-splines: 7860
#   Outer B-splines: 404
#   Inner element arrays: 7464
# Building extension matrix...
#   Extension matrix: 7860 x 404, nnz = 1932
# Assembling collocation matrix...
# line 1081 -> fiy this later!!!
# Solving linear system...
#   System dimension: 7860
#   Condition number: N/A (system too large)
# Evaluating solution...
#
# ========================================
# Results:
# ========================================
#   Relative max error: 6.492532e-15
#   Relative L2 error:  2.661171e-15
#   Mean absolute error: 3.816591e-16
#   Absolute L-inf error: 2.498002e-15
#   H1 semi-norm error: 9.537513e-02
#   H1 error:           9.537513e-02
#   Condition number:   N/A
#   System dimension:   7860
#
# Timing:
#   Classification/Assembly: 0.035s
#   Extension:               0.028s
#   Solution:                0.037s
#   Total:                   0.100s

# %%
importlib.reload(cWEB)
# Weight function - using analytical circle distance in [-1,1]² domain
#model = Geomertry.AnaliticalDistanceCircle()
model = Geomertry.AnaliticalDistanceCircle_smooth()
#model  = Geomertry.AnaliticalDistanceLshape()
#model = load_test_model("SIREN_L_3_0", "SIREN", params={"architecture": [2, 256, 256, 256, 1], "w_0": 80, "w_hidden": 120.0})
#model = Geomertry.AnaliticalDistanceLshape_RFunction()
res = cWEB.run_example(model=model, n=3, H=100, function_case=1, verbose=True)
# Out:
# ============================================================
# WEB-Spline Collocation: degree=3, H=100, domain={'x1': -1.0, 'x2': 1.0, 'y1': -1.0, 'y2': 1.0}, case=1
# ============================================================
# Domain transform: [0,1]² → [-1.0,1.0]×[-1.0,1.0]
# Laplacian factors in grid coords: ax=1/scale_x^2=2.500e-01, ay=1/scale_y^2=2.500e-01
# Classification...
#   Inner B-splines: 7829
#   Outer B-splines: 400
#   Inner element arrays: 7244
# Building extension matrix...
#   Extension matrix: 7829 x 400, nnz = 2488
# Assembling collocation matrix...
# Solving linear system...
#   System dimension: 7829
#   Condition number: N/A (system too large)
# Evaluating solution...
#
# ========================================
# Results:
# ========================================
#   Relative max error: 3.158566e-14
#   Relative L2 error:  2.347682e-14
#   Mean absolute error: 3.485640e-15
#   Absolute L-inf error: 1.215694e-14
#   H1 semi-norm error: 8.342205e-02
#   H1 error:           8.342205e-02
#   Condition number:   N/A
#   System dimension:   7829
#
# Timing:
#   Classification/Assembly: 0.072s
#   Extension:               0.044s
#   Solution:                0.055s
#   Total:                   0.171s

# %%
importlib.reload(cWEB)
model  = Geomertry.AnaliticalDistanceLshape()
res = cWEB.run_example(model=model, n=3, H=100, function_case=5, verbose=True)
# Out:
# ============================================================
# WEB-Spline Collocation: degree=3, H=100, domain={'x1': -1.0, 'x2': 1.0, 'y1': -1.0, 'y2': 1.0}, case=5
# ============================================================
# Domain transform: [0,1]² → [-1.0,1.0]×[-1.0,1.0]
# Laplacian factors in grid coords: ax=1/scale_x^2=2.500e-01, ay=1/scale_y^2=2.500e-01
# Classification...
#   Inner B-splines: 7701
#   Outer B-splines: 408
#   Inner element arrays: 7104
# Building extension matrix...
#   Extension matrix: 7701 x 408, nnz = 1692
# Assembling collocation matrix...
# Solving linear system...
#   System dimension: 7701
#   Condition number: N/A (system too large)
# Evaluating solution...
#
# ========================================
# Results:
# ========================================
#   Relative max error: 1.794329e+00
#   Relative L2 error:  1.488273e+00
#   Mean absolute error: 5.886012e-01
#   Absolute L-inf error: 1.787255e+00
#   H1 semi-norm error: 8.740312e-01
#   H1 error:           1.725945e+00
#   Condition number:   N/A
#   System dimension:   7701
#
# Timing:
#   Classification/Assembly: 0.128s
#   Extension:               0.075s
#   Solution:                0.045s
#   Total:                   0.247s

# %%
importlib.reload(cWEB)
model = Geomertry.AnaliticalDistanceLshape_RFunction()
res = cWEB.run_example(model=model, n=3, H=100, function_case=5, verbose=True)
# Out:
# ============================================================
# WEB-Spline Collocation: degree=3, H=100, domain={'x1': -1.0, 'x2': 1.0, 'y1': -1.0, 'y2': 1.0}, case=5
# ============================================================
# Domain transform: [0,1]² → [-1.0,1.0]×[-1.0,1.0]
# Laplacian factors in grid coords: ax=1/scale_x^2=2.500e-01, ay=1/scale_y^2=2.500e-01
# Classification...
#   Inner B-splines: 7695
#   Outer B-splines: 409
#   Inner element arrays: 7092
# Building extension matrix...
#   Extension matrix: 7695 x 409, nnz = 1756
# Assembling collocation matrix...
# Solving linear system...
#   System dimension: 7695
#   Condition number: N/A (system too large)
# Evaluating solution...
#
# ========================================
# Results:
# ========================================
#   Relative max error: 1.777962e-02
#   Relative L2 error:  6.632584e-03
#   Mean absolute error: 1.755926e-03
#   Absolute L-inf error: 1.770952e-02
#   H1 semi-norm error: 1.309861e-01
#   H1 error:           1.311540e-01
#   Condition number:   N/A
#   System dimension:   7695
#
# Timing:
#   Classification/Assembly: 0.148s
#   Extension:               0.046s
#   Solution:                0.047s
#   Total:                   0.240s

# %%
importlib.reload(cWEB)
from network_defs import load_test_model
model = load_test_model("random_circle", "SIREN", params={"architecture": [2, 256, 256, 256, 1], "w_0": 15, "w_hidden": 30})
res = cWEB.run_example(model=model, n=3, H=100, function_case=0, verbose=True)
# Out:
# ============================================================
# WEB-Spline Collocation: degree=3, H=100, domain={'x1': 0.0, 'x2': 1.0, 'y1': 0.0, 'y2': 1.0}, case=0
# ============================================================
# Domain transform: [0,1]² → [0.0,1.0]×[0.0,1.0]
# Laplacian factors in grid coords: ax=1/scale_x^2=1.000e+00, ay=1/scale_y^2=1.000e+00
# Classification...
#   Inner B-splines: 8154
#   Outer B-splines: 203
#   Inner element arrays: 7557
# Building extension matrix...
#   Extension matrix: 8154 x 203, nnz = 1292
# Assembling collocation matrix...
# Solving linear system...
#   System dimension: 8154
#   Condition number: N/A (system too large)
# Evaluating solution...
#
# ========================================
# Results:
# ========================================
#   Relative max error: 5.336447e-01
#   Relative L2 error:  3.464945e-01
#   Mean absolute error: 2.253925e-01
#   Absolute L-inf error: 9.169519e-01
#   H1 semi-norm error: 4.124924e-01
#   H1 error:           5.387099e-01
#   Condition number:   N/A
#   System dimension:   8154
#
# Timing:
#   Classification/Assembly: 1.223s
#   Extension:               0.023s
#   Solution:                0.082s
#   Total:                   1.328s

# %%
importlib.reload(cWEB)
model = Geomertry.AnaliticalDistanceCircle_smooth()
res = cWEB.run_example(model=model, n=2, H=10, function_case=1, verbose=True)
# Out:
# ============================================================
# WEB-Spline Collocation: degree=2, H=10, domain={'x1': -1.0, 'x2': 1.0, 'y1': -1.0, 'y2': 1.0}, case=1
# ============================================================
# Domain transform: [0,1]² → [-1.0,1.0]×[-1.0,1.0]
# Laplacian factors in grid coords: ax=1/scale_x^2=2.500e-01, ay=1/scale_y^2=2.500e-01
# Classification...
#   Inner B-splines: 80
#   Outer B-splines: 44
#   Inner element arrays: 44
# Building extension matrix...
#   Extension matrix: 80 x 44, nnz = 204
# Assembling collocation matrix...
# Solving linear system...
# Estimating condition number...
#   System dimension: 80
#   Condition number: 2.73e+01
# Evaluating solution...
#
# ========================================
# Results:
# ========================================
#   Relative max error: 9.001808e-16
#   Relative L2 error:  4.040939e-16
#   Mean absolute error: 5.943596e-17
#   Absolute L-inf error: 3.330669e-16
#   H1 semi-norm error: 3.553126e-01
#   H1 error:           3.553126e-01
#   Condition number:   2.73e+01
#   System dimension:   80
#
# Timing:
#   Classification/Assembly: 0.008s
#   Extension:               0.005s
#   Solution:                0.010s
#   Total:                   0.023s

# %%
importlib.reload(cWEB)
model = Geomertry.AnaliticalDistanceCircle()
res = cWEB
#   4 |  320 |   1.18e-07 |   3.80e-09 |   3.10e-09 |   9.36e-02 |   9.36e-02 |        nan |   8.995s
#   5 |   10 |   7.64e-03 |   3.10e-03 |   4.42e-03 |   2.47e-01 |   2.47e-01 |   5.24e+08 |   0.018s
#   5 |   20 |   2.89e-04 |   4.55e-05 |   4.66e-05 |   3.04e-01 |   3.04e-01 |   6.90e+07 |   0.142s
#   5 |   40 |   7.17e-05 |   6.27e-06 |   5.86e-06 |   2.23e-01 |   2.23e-01 |        nan |   0.273s
#   5 |   80 |   1.78e-05 |   8.52e-07 |   7.30e-07 |   1.65e-01 |   1.65e-01 |        nan |   0.383s
#   5 |  160 |   4.44e-06 |   1.15e-07 |   9.11e-08 |   1.12e-01 |   1.12e-01 |        nan |   2.017s
#   5 |  320 |   1.11e-06 |   1.53e-08 |   1.14e-08 |   8.12e-02 |   8.12e-02 |        nan |   9.163s
# --------------------------------------------------------------------------------------------------------------
# n=2, H: 10 -> 20, L2 order: 1.80
# n=2, H: 20 -> 40, L2 order: 1.90
# n=2, H: 40 -> 80, L2 order: 1.95
# n=2, H: 80 -> 160, L2 order: 1.98
# n=2, H: 160 -> 320, L2 order: 1.99
# n=3, H: 10 -> 20, L2 order: 2.18
# n=3, H: 20 -> 40, L2 order: 2.10
# n=3, H: 40 -> 80, L2 order: 2.06
# n=3, H: 80 -> 160, L2 order: 2.04
# n=3, H: 160 -> 320, L2 order: 2.02
# n=4, H: 10 -> 20, L2 order: 3.73
# n=4, H: 20 -> 40, L2 order: 2.66
# n=4, H: 40 -> 80, L2 order: 2.71
# n=4, H: 80 -> 160, L2 order: 2.78
# n=4, H: 160 -> 320, L2 order: 2.83
# n=5, H: 10 -> 20, L2 order: 6.09
# n=5, H: 20 -> 40, L2 order: 2.86
# n=5, H: 40 -> 80, L2 order: 2.88
# n=5, H: 80 -> 160, L2 order: 2.89
# n=5, H: 160 -> 320, L2 order: 2.90

# %%
importlib.reload(cWEB)
model = Geomertry.AnaliticalDistanceDisc_WEB()
res = cWEB.convergence_study(model=model, n_list=[2,3,4,5], H_list=[10, 20, 40, 80, 160, 320], function_case=0)
# Out:
# ==============================================================================================================
# Convergence Study (FUNCTION_CASE=0, domain={'x1': 0.0, 'x2': 1.0, 'y1': 0.0, 'y2': 1.0})
# ==============================================================================================================
#   n |    H |     ErrMax |      ErrL2 |        MAE |    H1_semi |     H1_err |       Cond |     Time
# --------------------------------------------------------------------------------------------------------------
#   2 |   10 |   2.99e-03 |   3.04e-03 |   2.11e-03 |   1.75e-01 |   1.75e-01 |   2.73e+01 |   0.055s
#   2 |   20 |   8.21e-04 |   8.80e-04 |   6.43e-04 |   1.17e-01 |   1.17e-01 |   1.09e+02 |   0.662s
#   2 |   40 |   2.09e-04 |   2.26e-04 |   1.67e-04 |   8.73e-02 |   8.73e-02 |        nan |   0.488s
#   2 |   80 |   5.24e-05 |   5.69e-05 |   4.23e-05 |   5.43e-02 |   5.43e-02 |        nan |   0.291s
#   2 |  160 |   1.31e-05 |   1.43e-05 |   1.06e-05 |   4.03e-02 |   4.03e-02 |        nan |   2.437s
#   2 |  320 |   3.28e-06 |   3.56e-06 |   2.65e-06 |   2.97e-02 |   2.97e-02 |        nan |  17.931s
#   3 |   10 |   4.24e-03 |   3.97e-03 |   3.16e-03 |   7.92e-02 |   7.93e-02 |   2.81e+01 |   0.023s
#   3 |   20 |   1.05e-03 |   9.77e-04 |   7.03e-04 |   9.07e-02 |   9.07e-02 |   1.11e+02 |   0.116s

# --------------------------------------------------------------------------------------------------------------
# n=2, H: 20 -> 40, L2 order: 1.90
# n=2, H: 40 -> 80, L2 order: 1.95
# n=2, H: 80 -> 160, L2 order: 1.98
# n=2, H: 160 -> 320, L2 order: 1.99
# n=3, H: 20 -> 40, L2 order: 2.10
# n=3, H: 40 -> 80, L2 order: 2.06
# n=3, H: 80 -> 160, L2 order: 2.04
# n=3, H: 160 -> 320, L2 order: 2.02
# n=4, H: 20 -> 40, L2 order: 2.66
# n=4, H: 40 -> 80, L2 order: 2.71
# n=4, H: 80 -> 160, L2 order: 2.78
# n=4, H: 160 -> 320, L2 order: 2.83
# n=5, H: 20 -> 40, L2 order: 2.86
# n=5, H: 40 -> 80, L2 order: 2.88
# n=5, H: 80 -> 160, L2 order: 2.89
# n=5, H: 160 -> 320, L2 order: 2.90

# %%
importlib.reload(cWEB)
model = Geomertry.AnaliticalDistance_CASE8()
res = cWEB.convergence_study(model=model, n_list=[2,3,4,5], H_list=[20, 40, 80, 160, 320], function_case=8)
# Out:
# ==============================================================================================================
# Convergence Study (FUNCTION_CASE=8, domain={'x1': -1.0, 'x2': 1.0, 'y1': -1.0, 'y2': 1.0})
# ==============================================================================================================
#   n |    H |     ErrMax |      ErrL2 |        MAE |    H1_semi |     H1_err |       Cond |     Time
# --------------------------------------------------------------------------------------------------------------
#   2 |   20 |   3.79e-02 |   1.78e-02 |   8.32e-03 |   5.14e-01 |   5.15e-01 |   1.30e+02 |   0.156s
#   2 |   40 |   2.48e-02 |   1.23e-02 |   5.94e-03 |   3.35e-01 |   3.35e-01 |        nan |   0.496s
#   2 |   80 |   9.35e-03 |   4.26e-03 |   2.03e-03 |   1.96e-01 |   1.96e-01 |        nan |   0.098s
#   2 |  160 |   2.64e-03 |   1.17e-03 |   5.53e-04 |   1.38e-01 |   1.38e-01 |        nan |   0.449s
#   2 |  320 |   6.77e-04 |   2.98e-04 |   1.41e-04 |   9.94e-02 |   9.94e-02 |        nan |   2.253s
#   3 |   20 |   2.17e-01 |   6.20e-02 |   2.82e-02 |   4.54e-01 |   4.59e-01 |   4.46e+04 |   0.061s
#   3 |   40 |   4.64e-02 |   1.71e-02 |   7.85e-03 |   2.80e-01 |   2.80e-01 |        nan |   0.100s
#   3 |   80 |   1.14e-02 |   4.72e-03 |   2.15e-03 |   1.86e-01 |   1.86e-01 |        nan |   0.104s
#   3 |  160 |   2.92e-03 |   1.20e-03 |   5.46e-04 |   1.22e-01 |   1.22e-01 |        nan |   0.450s
#   3 |  320 |   7.30e-04 |   3.00e-04 |   1.37e-04 |   8.68e-02 |   8.68e-02 |        nan |   2.109s
#   4 |   20 |   5.36e-02 |   1.21e-02 |   3.92e-03 |   5.16e-01 |   5.17e-01 |   1.56e+05 |   0.101s
#   4 |   40 |   5.19e-03 |   5.39e-04 |   1.79e-04 |   3.38e-01 |   3.38e-01 |        nan |   0.118s
#   4 |   80 |   1.01e-04 |   3.44e-05 |   1.45e-05 |   1.97e-01 |   1.97e-01 |        nan |   0.336s
#   4 |  160 |   1.10e-05 |   2.17e-06 |   9.22e-07 |   1.38e-01 |   1.38e-01 |        nan |   1.450s
#   4 |  320 |   2.30e-07 |   9.37e-08 |   4.07e-08 |   9.95e-02 |   9.95e-02 |        nan |   8.051s
#   5 |   20 |   7.31e+00 |   1.41e+00 |   3.52e-01 |   2.10e+00 |   2.52e+00 |   7.38e+11 |   0.179s
#   5 |   40 |   9.50e-02 |   6.43e-03 |   1.51e-03 |   2.85e-01 |   2.85e-01 |        nan |   0.096s
#   5 |   80 |   5.80e-04 |   6.67e-05 |   1.98e-05 |   1.87e-01 |   1.87e-01 |        nan |   0.296s
#   5 |  160 |   1.06e-05 |   1.07e-06 |   4.00e-07 |   1.23e-01 |   1.23e-01 |        nan |   1.704s
#   5 |  320 |   9.63e-08 |   2.90e-08 |   1.26e-08 |   8.68e-02 |   8.68e-02 |        nan |   7.888s
# --------------------------------------------------------------------------------------------------------------
# n=2, H: 20 -> 40, L2 order: 0.53
# n=2, H: 40 -> 80, L2 order: 1.53
# n=2, H: 80 -> 160, L2 order: 1.87
# n=2, H: 160 -> 320, L2 order: 1.97
# n=3, H: 20 -> 40, L2 order: 1.86
# n=3, H: 40 -> 80, L2 order: 1.86
# n=3, H: 80 -> 160, L2 order: 1.98
# n=3, H: 160 -> 320, L2 order: 2.00
# n=4, H: 20 -> 40, L2 order: 4.49
# n=4, H: 40 -> 80, L2 order: 3.97
# n=4, H: 80 -> 160, L2 order: 3.98
# n=4, H: 160 -> 320, L2 order: 4.53
# n=5, H: 20 -> 40, L2 order: 7.77
# n=5, H: 40 -> 80, L2 order: 6.59
# n=5, H: 80 -> 160, L2 order: 5.96
# n=5, H: 160 -> 320, L2 order: 5.21

# %%
importlib.reload(FEM)
importlib.reload(cWEB)
importlib.reload(Geomertry)
# Weight function - using analytical circle distance in [-1,1]² domain
model = Geomertry.AnaliticalDistanceDisc_WEB()
#model = Geomertry.AnaliticalDistanceCircle()
#model = Geomertry.AnaliticalDistanceCircle_smooth()
#model  = Geomertry.AnaliticalDistanceLshape()
#model = load_test_model("SIREN_L_3_0", "SIREN", params={"architecture": [2, 256, 256, 256, 1], "w_0": 80, "w_hidden": 120.0})
#model = Geomertry.AnaliticalDistanceLshape_RFunction()
res = cWEB.run_example(model=model, n=4, H=100, function_case=0, verbose=True)
# Out:
# ============================================================
# WEB-Spline Collocation: degree=4, H=100, domain={'x1': 0.0, 'x2': 1.0, 'y1': 0.0, 'y2': 1.0}, case=0
# ============================================================
# Domain transform: [0,1]² → [0.0,1.0]×[0.0,1.0]
# Laplacian scale factor: 1.0
# Classification...
#   Inner B-splines: 7860
#   Outer B-splines: 816
#   Inner element arrays: 7076
# Building extension matrix...
#   Extension matrix: 7860 x 816, nnz = 8440
# Assembling collocation matrix...
# Solving linear system...
#   System dimension: 7860
#   Condition number: N/A (system too large)
# Evaluating solution...
#
# ========================================
# Results:
# ========================================
#   Relative max error: 5.811327e-09
#   Relative L2 error:  5.481712e-09
#   Mean absolute error: 3.870547e-09
#   Absolute L-inf error: 9.982339e-09
#   H1 semi-norm error: 5.131433e-02
#   H1 error:           5.131433e-02
#   Condition number:   N/A
#   System dimension:   7860
#
# Timing:
#   Classification/Assembly: 0.523s
#   Extension:               0.244s
#   Solution:                1.455s
#   Total:                   2.222s

# %%
importlib.reload(FEM)
importlib.reload(cWEB)
importlib.reload(Geomertry)
# Weight function - using analytical circle distance in [-1,1]² domain
model = Geomertry.AnaliticalDistance_CASE8()
#model = Geomertry.AnaliticalDistanceCircle()
#model = Geomertry.AnaliticalDistanceCircle_smooth()
#model  = Geomertry.AnaliticalDistanceLshape()
#model = load_test_model("SIREN_L_3_0", "SIREN", params={"architecture": [2, 256, 256, 256, 1], "w_0": 80, "w_hidden": 120.0})
#model = Geomertry.AnaliticalDistanceLshape_RFunction()
res = cWEB.run_example(model=model, n=2, H=20, function_case=8, verbose=True)
# Out:
# ============================================================
# WEB-Spline Collocation: degree=2, H=20, domain={'x1': -4.0, 'x2': 4.0, 'y1': -3.0, 'y2': 3.0}, case=8
# ============================================================
# Domain transform: [0,1]² → [-4.0,4.0]×[-3.0,3.0]
# Laplacian scale factor: 48.0
# Classification...
#   Inner B-splines: 290
#   Outer B-splines: 104
#   Inner element arrays: 186
# Building extension matrix...
#   Extension matrix: 290 x 104, nnz = 492
# Assembling collocation matrix...
# Solving linear system...
# Estimating condition number...
#   System dimension: 290
#   Condition number: 1.30e+02
# Evaluating solution...
#
# ========================================
# Results:
# ========================================
#   Relative max error: 2.393708e-01
#   Relative L2 error:  1.576324e-01
#   Mean absolute error: 8.691049e-02
#   Absolute L-inf error: 2.393705e-01
#   H1 semi-norm error: 5.368446e-01
#   H1 error:           5.595088e-01
#   Condition number:   1.30e+02
#   System dimension:   290
#
# Timing:
#   Classification/Assembly: 0.019s
#   Extension:               0.014s
#   Solution:                0.406s
#   Total:                   0.439s

# %%
importlib.reload(FEM)
importlib.reload(cWEB)
importlib.reload(Geomertry)
# Weight function - using analytical circle distance in [-1,1]² domain
#model = Geomertry.AnaliticalDistanceDisc_WEB()
model = Geomertry.AnaliticalDistanceCircle()
#model = Geomertry.AnaliticalDistanceCircle_smooth()
#model  = Geomertry.AnaliticalDistanceLshape()
#model = load_test_model("SIREN_L_3_0", "SIREN", params={"architecture": [2, 256, 256, 256, 1], "w_0": 80, "w_hidden": 120.0})
#model = Geomertry.AnaliticalDistanceLshape_RFunction()
res = cWEB.run_example(model=model, n=2, H=100, function_case=2, verbose=True)
# Out:
# ============================================================
# WEB-Spline Collocation: degree=2, H=100, domain={'x1': -1.0, 'x2': 1.0, 'y1': -1.0, 'y2': 1.0}, case=2
# ============================================================
# Domain transform: [0,1]² → [-1.0,1.0]×[-1.0,1.0]
# Laplacian scale factor: 4.0
# Classification...
#   Inner B-splines: 7860
#   Outer B-splines: 404
#   Inner element arrays: 7464
# Building extension matrix...
#   Extension matrix: 7860 x 404, nnz = 1932
# Assembling collocation matrix...
# Solving linear system...
#   System dimension: 7860
#   Condition number: N/A (system too large)
# Evaluating solution...
#
# ========================================
# Results:
# ========================================
#   Relative max error: 2.402009e-02
#   Relative L2 error:  5.572227e-03
#   Mean absolute error: 2.813608e-03
#   Absolute L-inf error: 2.402008e-02
#   H1 semi-norm error: N/A
#   H1 error:           N/A
#   Condition number:   N/A
#   System dimension:   7860
#
# Timing:
#   Classification/Assembly: 0.072s
#   Extension:               0.033s
#   Solution:                4.060s
#   Total:                   4.166s

# %%
importlib.reload(FEM)
importlib.reload(cWEB)
importlib.reload(Geomertry)
# Weight function - using analytical circle distance in [-1,1]² domain
#model = Geomertry.AnaliticalDistanceDisc_WEB()
model = Geomertry.AnaliticalDistanceCircle()
#model = Geomertry.AnaliticalDistanceCircle_smooth()
#model  = Geomertry.AnaliticalDistanceLshape()
#model = load_test_model("SIREN_L_3_0", "SIREN", params={"architecture": [2, 256, 256, 256, 1], "w_0": 80, "w_hidden": 120.0})
#model = Geomertry.AnaliticalDistanceLshape_RFunction()
res = cWEB.run_example(model=model, n=4, H=300, function_case=3, verbose=True)
# Out:
# ============================================================
# WEB-Spline Collocation: degree=4, H=300, domain={'x1': -1.0, 'x2': 1.0, 'y1': -1.0, 'y2': 1.0}, case=3
# ============================================================
# Domain transform: [0,1]² → [-1.0,1.0]×[-1.0,1.0]
# Laplacian scale factor: 4.0
# Classification...
#   Inner B-splines: 70688
#   Outer B-splines: 2416
#   Inner element arrays: 68304
# Building extension matrix...
#   Extension matrix: 70688 x 2416, nnz = 23480
# Assembling collocation matrix...
# Solving linear system...
#   System dimension: 70688
#   Condition number: N/A (system too large)
# Evaluating solution...
#
# ========================================
# Results:
# ========================================
#   Relative max error: 1.335783e-07
#   Relative L2 error:  4.574245e-09
#   Mean absolute error: 3.753203e-09
#   Absolute L-inf error: 3.185699e-07
#   H1 semi-norm error: 9.281640e-02
#   H1 error:           9.281640e-02
#   Condition number:   N/A
#   System dimension:   70688
#
# Timing:
#   Classification/Assembly: 1.246s
#   Extension:               0.974s
#   Solution:                23.655s
#   Total:                   25.875s
