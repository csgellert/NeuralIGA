# %%
import torch
import NeuralImplicit

# %%
relu_model = NeuralImplicit.NeuralNetwork(2,256,2,1)
total_steps = 500
steps_til_summary = total_steps/10

optim = torch.optim.Adam(lr=1e-3, params=relu_model.parameters())

# %%
relu_model.train_network(optim,total_steps,steps_til_summary)
# Out:
# Step 0, Total loss 0.300968
# Step 50, Total loss 0.179295
# Step 100, Total loss 0.177685
# Step 150, Total loss 0.181490
# Step 200, Total loss 0.180312
# Step 250, Total loss 0.180920
# Step 300, Total loss 0.178052
# Step 350, Total loss 0.176342
# Step 400, Total loss 0.174531
# Step 450, Total loss 0.180823
# Step 499, Total loss 0.176894

# %%
NeuralImplicit.plotDisctancefunction(relu_model,100,contour = True)

# %%
relu_model.save()
# Out:
# Model saved successfully
