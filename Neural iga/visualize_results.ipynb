# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#code from 2024.10.27.
# negyzetes tavolsag a korre (siren)
#model error 1.4401e-07
test_values_v0 = np.array([2,6,14,20,30,40,50,60,70,80,120,150])
mask1_v0 = np.array([False,False,False,False,True,True,True,True,True,True,True,False],dtype=np.bool8)
mask_all_v0 = np.ones_like(mask1_v0)
mask_v0 = mask1_v0
esize_v0 = np.array([1/(nd+1) for nd in test_values_v0],dtype=np.float32)
MSE1_v0 = np.array([0.00064582,2.3073011e-05,1.4173708e-06,4.208904e-07,2.0358682e-07,1.7508637e-07,1.125297e-07,7.7746684e-08,5.549753e-08,4.195316e-08,2.3368441e-08,2.5259087e-08])
MSE2_v0 = np.array([8.767728e-06,7.923716e-07,2.5704358e-07,2.005082e-07,1.5010642e-07,1.3746286e-07,9.76022e-08,5.8070047e-08,2.987723e-08,2.1085805e-08,1.6276847e-08,2.148544e-08])
MSE3_v0 = np.array([3.3133745e-06,5.3852193e-07,2.5285578e-07,1.9312496e-07,1.5456618e-07,1.3048265e-07,9.845559e-08,4.830123e-08,2.862739e-08,1.8103261e-08,1.1710277e-08,1.495267e-06])
etypes_v0 = [{'outer': 0, 'inner': 1, 'boundary': 8}, {'outer': 4, 'inner': 21, 'boundary': 24}, {'outer': 24, 'inner': 145, 'boundary': 56}, {'outer': 68, 'inner': 293, 'boundary': 80},{'outer': 168, 'inner': 673, 'boundary': 120}, {'outer': 304, 'inner': 1217, 'boundary': 160}, {'outer': 484, 'inner': 1917, 'boundary': 200}, {'outer': 724, 'inner': 2757, 'boundary': 240},{'outer': 992, 'inner': 3769, 'boundary': 280},{'outer': 1312, 'inner': 4929, 'boundary': 320},{'outer': 3012, 'inner': 11149, 'boundary': 480},{'outer': 4748, 'inner': 17453, 'boundary': 600}]
inner_v0 = np.array([case["inner"] for case in etypes_v0])
outer_v0 = np.array([case["outer"] for case in etypes_v0])
boundary_v0 = np.array([case["boundary"] for case in etypes_v0])

case_v0 = {'name':'v0','MSE1':MSE1_v0,'MSE2':MSE2_v0,'MSE3':MSE3_v0,'mask':mask_v0,'test_values':test_values_v0,'esize':esize_v0,'inner':inner_v0,'outer':outer_v0,'boundary':boundary_v0}

# %%
#code from 2024.10.30.
# Jó távolság kör
# model_error 7.5410e-08
test_values_euk = np.array([20,30,40,50,60,80,120])
mask1_euk = np.array([True,True,True,True, True,True,True],dtype=np.bool8)
mask_all_euk = np.ones_like(mask1_euk)
mask_euk = mask_all_euk
esize_euk = np.array([1/(nd+1) for nd in test_values_euk],dtype=np.float32)
MSE1_euk = np.array([None,1.2644364e-06,8.7417897e-07,4.2272055e-07,2.8226762e-07,1.6692313e-07,None])
MSE2_euk = np.array([None,3.6959096e-07,3.6088798e-07,2.719417e-07,1.666299e-07,1.17588954e-07,None])
MSE3_euk = np.array([None,4.4035892e-07,3.6137956e-07,2.5843775e-07,1.6184269e-07,1.18233295e-07,None])
etypes_euk = [{'outer': 68, 'inner': 293, 'boundary': 80}, {'outer': 168, 'inner': 673, 'boundary': 120}, {'outer': 304, 'inner': 1217, 'boundary': 160},{'outer': 484, 'inner': 1917, 'boundary': 200}, {'outer': 724, 'inner': 2757, 'boundary': 240}, {'outer': 1311, 'inner': 4930, 'boundary': 320}, {'outer': 3010, 'inner': 11151, 'boundary': 480}]
inner_euk = np.array([case["inner"] for case in etypes_euk])
outer_euk = np.array([case["outer"] for case in etypes_euk])
boundary_euk = np.array([case["boundary"] for case in etypes_euk])

case_euk = {'name':'euk','MSE1':MSE1_euk,'MSE2':MSE2_euk,'MSE3':MSE3_euk,'mask':mask_euk,'test_values':test_values_euk,'esize':esize_euk,'inner':inner_euk,'outer':outer_euk,'boundary':boundary_euk}

# %%
## Euklideszi távolság HELYETT ez is kvadratikus


#code from 2024.10.29.
# model_error 7.4724e-07
test_values_v1 = np.array([20,30,40,60,70,80,100,120])
mask1_v1 = np.array([True,True,True,True,True,True,True,True],dtype=np.bool8)
mask_all_v1 = np.ones_like(mask1_v1)
mask_v1 = mask_all_v1
esize_v1 = np.array([1/(nd+1) for nd in test_values_v1],dtype=np.float32)
MSE1_v1 = np.array([6.4799343e-07,3.8638566e-07,3.6488703e-07,1.9485438e-07,1.4808646e-07,1.2472998e-07,9.8935246e-08,9.012398e-08])
MSE2_v1 = np.array([3.9763108e-07,3.2838744e-07,2.9436728e-07,1.4101315e-07,1.04895214e-07,8.2690434e-08,7.130303e-08,6.9273064e-08])
MSE3_v1 = np.array([None,3.255282e-07,3.04149e-07,1.3964322e-07,9.0006004e-08,7.430534e-08,8.123662e-08,7.031759e-08])
etypes_v1 = [{'outer': 68, 'inner': 293, 'boundary': 80}, {'outer': 168, 'inner': 673, 'boundary': 120}, {'outer': 304, 'inner': 1217, 'boundary': 160}, {'outer': 724, 'inner': 2757, 'boundary': 240},{'outer': 992, 'inner': 3769, 'boundary': 280},{'outer': 1312, 'inner': 4929, 'boundary': 320},{'outer': 2080, 'inner': 7721, 'boundary': 400},{'outer': 3012, 'inner': 11149, 'boundary': 480}]
inner_v1 = np.array([case["inner"] for case in etypes_v1])
outer_v1 = np.array([case["outer"] for case in etypes_v1])
boundary_v1 = np.array([case["boundary"] for case in etypes_v1])

case_v1 = {'name':'v1','MSE1':MSE1_v1,'MSE2':MSE2_v1,'MSE3':MSE3_v1,'mask':mask_v1,'test_values':test_values_v1,'esize':esize_v1,'inner':inner_v1,'outer':outer_v1,'boundary':boundary_v1}

# %%
#Analitical distance function (quadratic)

#code from 2024.10.30.
# negyzetes tavolsag a korre
test_values_a2 = np.array([20,30,40,80,120])
mask1_a2 = np.array([True, True,True,True,True],dtype=np.bool8)
mask_all_a2 = np.ones_like(mask1_a2)
mask_a2 = mask_all_a2
esize_a2 = np.array([1/(nd+1) for nd in test_values_a2],dtype=np.float32)
MSE1_a2 = np.array([None,None,None,None,None])
MSE2_a2 = np.array([1.5908479268927728e-09,7.641332436841476e-10,5.738550630675184e-10,2.1946315657327712e-11,7.833249629592726e-12])
MSE3_a2 = np.array([None,None,None,None,None])
etypes_a2 = [{'outer': 68, 'inner': 293, 'boundary': 80}, {'outer': 168, 'inner': 673, 'boundary': 120}, {'outer': 304, 'inner': 1217, 'boundary': 160}, {'outer': 1311, 'inner': 4930, 'boundary': 320}, {'outer': 3010, 'inner': 11151, 'boundary': 480}]
inner_a2 = np.array([case["inner"] for case in etypes_a2])
outer_a2 = np.array([case["outer"] for case in etypes_a2])
boundary_a2 = np.array([case["boundary"] for case in etypes_a2])

case_a2 = {'name':'a2','MSE1':MSE1_a2,'MSE2':MSE2_a2,'MSE3':MSE3_a2,'mask':mask_a2,'test_values':test_values_a2,'esize':esize_a2,'inner':inner_a2,'outer':outer_a2,'boundary':boundary_a2}

# %%
#Analitical distance function (euclidian)

#code from 2024.10.31.
# euklideszi tavolsag a korre
test_values_a1 = np.array([20,40,80,120])
mask1_a1 = np.array([True,True,True,True],dtype=np.bool8)
mask_all_a1 = np.ones_like(mask1_a1)
mask_a1 = mask_all_a1
esize_a1 = np.array([1/(nd+1) for nd in test_values_a1],dtype=np.float32)
MSE1_a1 = np.array([None,None,None,None])
MSE2_a1 = np.array([7.2415692701316975e-06,1.2959870919938202e-06,2.7606222588704347e-07,1.6621451191388064e-07])
MSE3_a1 = np.array([None,None,None,None])
etypes_a1 = [{'outer': 68, 'inner': 293, 'boundary': 80}, {'outer': 304, 'inner': 1217, 'boundary': 160},{'outer': 1311, 'inner': 4930, 'boundary': 320},{'outer': 3010, 'inner': 11151, 'boundary': 480}]
inner_a1 = np.array([case["inner"] for case in etypes_a1])
outer_a1 = np.array([case["outer"] for case in etypes_a1])
boundary_a1 = np.array([case["boundary"] for case in etypes_a1])

case_a1 = {'name':'a1','MSE1':MSE1_a1,'MSE2':MSE2_a1,'MSE3':MSE3_a1,'mask':mask_a1,'test_values':test_values_a1,'esize':esize_a1,'inner':inner_a1,'outer':outer_a1,'boundary':boundary_a1}

# %%
# 2025.06.13 Analitical distance - euclidan distance
#case a_new
#however, there was an error in the evaluation, Larger_Domain was set to False by elvaluation

test_values_a_new = np.array([10,20,30,40,60,80,100])
mask1_a_new = np.array([True,True,True,True,True,True,True],dtype=np.bool8)
mask_all_a_new = np.ones_like(mask1_a_new)
mask_a_new = mask_all_a_new
esize_a_new = np.array([1/(nd+1) for nd in test_values_a_new],dtype=np.float32)
MSE1_a_new = np.array([5.593635664606271e-05,6.639234769842905e-06,1.8935200346520366e-06,8.879503349587472e-07,3.367524004791371e-07,1.7997211395787968e-07,1.0996668974276022e-07])
MSE2_a_new = np.array([1.5918814344654005e-06,2.817351131962251e-07,1.217899642408333e-07,6.798778120641432e-08,2.9941690419619776e-08,1.7040918420249792e-08, 1.107668010558066e-08])
MSE3_a_new = np.array([7.703520052405193e-06,1.1200154260052668e-06,3.900608055821828e-07,2.0262513306219774e-07,9.013874226903851e-08,4.98416618248349e-08,3.1524993390167636e-08])
etypes_a_new = [{'outer': 12, 'inner': 69, 'boundary': 40}, {'outer': 68, 'inner': 293, 'boundary': 80}, {'outer': 168, 'inner': 673, 'boundary': 120}, {'outer': 304, 'inner': 1217, 'boundary': 160}, {'outer': 724, 'inner': 2757, 'boundary': 240}, {'outer': 1312, 'inner': 4929, 'boundary': 320}, {'outer': 2080, 'inner': 7721, 'boundary': 400}]
inner_a_new = np.array([case["inner"] for case in etypes_a_new])
outer_a_new = np.array([case["outer"] for case in etypes_a_new])
boundary_a_new = np.array([case["boundary"] for case in etypes_a_new])

case_a_new = {'name':'a1','MSE1':MSE1_a_new,'MSE2':MSE2_a_new,'MSE3':MSE3_a_new,'mask':mask_a_new,'test_values':test_values_a_new,'esize':esize_a_new,'inner':inner_a_new,'outer':outer_a_new,'boundary':boundary_a_new}

# %%
cases = [
        #case_a2,
        #case_v0,
        case_euk,
        #case_v1,
        #case_a1,
        #case_a_new
        ]
ccase = case_euk

# %%
labels = []
for c in cases:
    plt.yscale('log')
    plt.xscale('log')
    labels.append(c['name'])
    #plt.plot(c['esize'][c['mask']],c['MSE3'][c['mask']],'*-')
    plt.plot(c['esize'][c['mask']],c['MSE2'][c['mask']],'*-')
    #plt.plot(c['esize'][c['mask']],c['MSE1'][c['mask']],'*-')
plt.legend(labels)
plt.show()

# %%
plt.yscale('log')
plt.xscale('log')
plt.plot(ccase['esize'][ccase['mask']],ccase['MSE3'][ccase['mask']],'*-')
plt.plot(ccase['esize'][ccase['mask']],ccase['MSE2'][ccase['mask']],'*-')
plt.plot(ccase['esize'][ccase['mask']],ccase['MSE1'][ccase['mask']],'*-')
plt.legend(['p=3','p=2','p=1'])
plt.title('Effect of refinment for MSE')
plt.xlabel('element size')
plt.ylabel('MSE')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
plt.yscale('log')
plt.xscale('log')
plt.plot(ccase['esize'][:],ccase['MSE1'][:],'*-')
plt.plot(ccase['esize'][:],ccase['MSE2'][:],'*-')
plt.plot(ccase['esize'][:],ccase['MSE3'][:],'*-')
#slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(ccase['esize'][5:10]), np.log(ccase['MSE1'][5:10]))
#print(slope)
# model = LinearRegression().fit(np.log(ccase['esize'][5:10].reshape(-1,1)),np.log(ccase['MSE1'][5:10]))
# print(model.coef_)
# plt.plot(ccase['esize'][:],np.exp(model.predict(np.log(ccase['esize'][:].reshape(-1,1)))),'r--')

model = LinearRegression().fit(np.log(ccase['esize'][:].reshape(-1,1)),np.log(ccase['MSE2'][:]))
print(model.coef_)
plt.plot(ccase['esize'][:],np.exp(model.predict(np.log(ccase['esize'][:].reshape(-1,1)))),'r--')

# model = LinearRegression().fit(np.log(ccase['esize'][6:10].reshape(-1,1)),np.log(ccase['MSE3'][6:10]))
# print(model.coef_)
# plt.plot(ccase['esize'][:],np.exp(model.predict(np.log(ccase['esize'][:].reshape(-1,1)))),'r--')


plt.legend(['p=1','p=2','p=3'])
plt.title('Effect of refinment for MSE')
plt.xlabel('element size')
plt.ylabel('MSE')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'NoneType' object has no attribute 'log'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 13
#       6 plt.plot(ccase['esize'][:],ccase['MSE3'][:],'*-')
#       7 #slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(ccase['esize'][5:10]), np.log(ccase['MSE1'][5:10]))
#       8 #print(slope)
#       9 # model = LinearRegression().fit(np.log(ccase['esize'][5:10].reshape(-1,1)),np.log(ccase['MSE1'][5:10]))
#      10 # print(model.coef_)
#      11 # plt.plot(ccase['esize'][:],np.exp(model.predict(np.log(ccase['esize'][:].reshape(-1,1)))),'r--')
# ---> 13 model = LinearRegression().fit(np.log(ccase['esize'][:].reshape(-1,1)),np.log(ccase['MSE2'][:]))
#      14 print(model.coef_)
# ...

# %%
from sklearn.linear_model import LinearRegression
from scipy import stats
plt.yscale('log')
plt.xscale('log')
plt.plot(ccase['esize'][ccase['mask']],ccase['MSE1'][ccase['mask']],'*-')
plt.plot(ccase['esize'][ccase['mask']],ccase['MSE2'][ccase['mask']],'*-')
plt.plot(ccase['esize'][ccase['mask']],ccase['MSE3'][ccase['mask']],'*-')

slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(ccase['esize'][5:10]), np.log(ccase['MSE1'][5:10]))
print(slope)
model = LinearRegression().fit(np.log(ccase['esize'][5:10].reshape(-1,1)),np.log(ccase['MSE1'][5:10]))
print(model.coef_)

plt.plot(ccase['esize'][ccase['mask']],np.exp(model.predict(np.log(ccase['esize'][ccase['mask']].reshape(-1,1)))))
slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(ccase['esize'][6:10]), np.log(ccase['MSE2'][6:10]))
print(slope)
model = LinearRegression().fit(np.log(ccase['esize'][6:10].reshape(-1,1)),np.log(ccase['MSE2'][6:10]))
print(model.coef_)
plt.plot(ccase['esize'][ccase['mask']],np.exp(model.predict(np.log(ccase['esize'][ccase['mask']].reshape(-1,1)))))

model = LinearRegression().fit(np.log(ccase['esize'][6:10].reshape(-1,1)),np.log(ccase['MSE3'][6:10]))
print(model.coef_)
plt.plot(ccase['esize'][ccase['mask']],np.exp(model.predict(np.log(ccase['esize'][ccase['mask']].reshape(-1,1)))))


plt.legend(['p=1','p=2','p=3'])
plt.title('Effect of refinment for MSE')
plt.xlabel('element size')
plt.ylabel('MSE')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'float' object has no attribute 'log'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       6 plt.plot(ccase['esize'][ccase['mask']],ccase['MSE2'][ccase['mask']],'*-')
#       7 plt.plot(ccase['esize'][ccase['mask']],ccase['MSE3'][ccase['mask']],'*-')
# ----> 9 slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(ccase['esize'][5:10]), np.log(ccase['MSE1'][5:10]))
#      10 print(slope)
#      11 model = LinearRegression().fit(np.log(ccase['esize'][5:10].reshape(-1,1)),np.log(ccase['MSE1'][5:10]))
#
# TypeError: loop of ufunc does not support argument 0 of type float which has no callable log method

# %%
plt.yscale('log')
plt.xscale('log')
plt.plot(ccase['esize'][ccase['mask']],(ccase['outer'][ccase['mask']]),'*-')
plt.plot(ccase['esize'][ccase['mask']],(ccase['inner'][ccase['mask']]),'*-')
plt.plot(ccase['esize'][ccase['mask']],(ccase['boundary'][ccase['mask']]),'*-')
plt.legend(['outer element','innner element','boundary element'])
plt.title('Number of elements per category')
plt.xlabel('log(element size)')
plt.ylabel('log(Number of element)')
plt.show()

# %%
plt.yscale('log')
plt.xscale('log')
plt.plot(ccase['esize'][ccase['mask']],ccase['MSE3'][ccase['mask']],'*-')
plt.plot(ccase['esize'][ccase['mask']],ccase['MSE2'][ccase['mask']],'*-')
plt.plot(ccase['esize'][ccase['mask']],ccase['MSE1'][ccase['mask']],'*-')
plt.show()

# %%
plt.yscale('log')
plt.xscale('log')
plt.plot((ccase['inner']+ccase['boundary'])[ccase['mask']],ccase['MSE3'][ccase['mask']],'*-')
plt.plot((ccase['inner']+ccase['boundary'])[ccase['mask']],ccase['MSE1'][ccase['mask']],'*-')
plt.plot((ccase['inner']+ccase['boundary'])[ccase['mask']],ccase['MSE2'][ccase['mask']],'*-')
plt.show()

# %%
import torch
from NeuralImplicit import Siren, plotDisctancefunction
siren_model_euk = Siren(in_features=2,out_features=1,hidden_features=256,hidden_layers=2,outermost_linear=True)
siren_model_euk.load_state_dict(torch.load('siren_model_kor_jo.pth',weights_only=True,map_location=torch.device('cpu')))
siren_model_euk.eval()

model = siren_model_euk
plotDisctancefunction(model,50,True)
print(model.get_model_mse(fun_num=2))
# Out:
# tensor(7.3729e-08, grad_fn=<MeanBackward0>)

# %%
import Geomertry
analitical_model2 = Geomertry.AnaliticalDistanceLshape()
model = analitical_model2

model.contour_plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 5
#       2 analitical_model2 = Geomertry.AnaliticalDistanceLshape()
#       3 model = analitical_model2
# ----> 5 model.contour_plot()
#
# File c:\Egyetem\Diploma\Diplomamunka\.venv\lib\site-packages\torch\nn\modules\module.py:1915, in Module.__getattr__(self, name)
#    1913     if name in modules:
#    1914         return modules[name]
# -> 1915 raise AttributeError(
#    1916     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1917 )
#
# AttributeError: 'AnaliticalDistanceLshape' object has no attribute 'contour_plot'
