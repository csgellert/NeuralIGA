# %%
import evaluation as eva

# %%
filepath = "./simulation_results/simm_res_L_analytic.json"
eva.visualize_results(filepath, metric='L_inf', log_scale=True)
# Out:
# Results from: ./simulation_results/simm_res_L_analytic.json
# Timestamp: 2026-01-12T15:42:46.705096
#
# L_inf values:
# --------------------------------------------------
#
# Order p = 1:
#   div= 10 (h=0.0909): 2.351212e-01
#   div= 20 (h=0.0476): 7.449668e-02
#   div= 50 (h=0.0196): 2.821957e-02
#   div= 80 (h=0.0123): 2.022560e-02
#   div=100 (h=0.0099): 1.453607e-02
#   div=120 (h=0.0083): 1.249077e-02
#   div=150 (h=0.0066): 9.649727e-03
#
# Order p = 2:
#   div= 10 (h=0.0909): 9.840153e-02
#   div= 20 (h=0.0476): 6.438176e-02
#   div= 50 (h=0.0196): 2.941891e-02
#   div= 80 (h=0.0123): 1.701916e-02
#   div=100 (h=0.0099): 1.475440e-02
#   div=120 (h=0.0083): 1.344814e-02
#   div=150 (h=0.0066): 1.051421e-02
#
# Order p = 3:
#   div= 10 (h=0.0909): 8.265204e-02
#   div= 20 (h=0.0476): 5.263639e-02
#   div= 50 (h=0.0196): 2.531549e-02
#   div= 80 (h=0.0123): 1.655219e-02
#   div=100 (h=0.0099): 1.353869e-02
#   div=120 (h=0.0083): 1.118814e-02
# ...

# %%
# Compare multiple simulation files
filepaths = [
    "simulation_results\\simm_res_L_analytic.json",
    "simulation_results\\simulation_results_AnalyticalDistanceLshapeTanh_20260114_122013.json"
]

# Show orders 1 and 2 for all files
eva.compare_simulations(
    filepaths=filepaths,
    orders_to_show=[3],
    metric='MAE',
    log_scale=True,
    labels=['Analytical', 'Analytical Tanh']  # Optional custom labels
)
# Out:
# ...
# Comparison Summary - Metric: MAE
# ...
#
# Analytical:
# --------------------------------------------------
#   Order p = 3:
#     div= 10 (h=0.0909): 1.495987e-02
#     div= 20 (h=0.0476): 6.787800e-03
#     div= 50 (h=0.0196): 2.131980e-03
#     div= 80 (h=0.0123): 1.391124e-03
#     div=100 (h=0.0099): 1.256215e-03
#     div=120 (h=0.0083): 1.235091e-03
#     div=150 (h=0.0066): 1.322000e-03
#
# Analytical Tanh:
# --------------------------------------------------
#   Order p = 3:
#     div= 10 (h=0.0909): 1.341056e-02
#     div= 20 (h=0.0476): 6.070435e-03
#     div= 50 (h=0.0196): 1.946801e-03
#     div= 80 (h=0.0123): 1.284450e-03
#     div=100 (h=0.0099): 1.131250e-03
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Comparison of MAE Convergence'}, xlabel='Element Size (h)', ylabel='MAE'>)

# %%
filepath = "./simulation_results/simulation_results_AnalyticalDistanceLshapeTanh_20260114_122013.json"
eva.visualize_results(filepath, metric='MAE', log_scale=True)
# Out:
# Results from: ./simulation_results/simulation_results_AnalyticalDistanceLshapeTanh_20260114_122013.json
# Timestamp: 2026-01-14T12:20:13.883182
#
# MAE values:
# --------------------------------------------------
#
# Order p = 1:
#   div= 10 (h=0.0909): 3.339763e-02
#   div= 20 (h=0.0476): 1.273743e-02
#   div= 50 (h=0.0196): 4.938105e-03
#   div= 80 (h=0.0123): 3.198530e-03
#   div=100 (h=0.0099): 3.000428e-03
#
# Order p = 2:
#   div= 10 (h=0.0909): 1.363822e-02
#   div= 20 (h=0.0476): 6.977666e-03
#   div= 50 (h=0.0196): 3.489921e-03
#   div= 80 (h=0.0123): 2.487968e-03
#   div=100 (h=0.0099): 2.405434e-03
#
# Order p = 3:
#   div= 10 (h=0.0909): 1.341056e-02
#   div= 20 (h=0.0476): 6.070435e-03
#   div= 50 (h=0.0196): 1.946801e-03
#   div= 80 (h=0.0123): 1.284450e-03
#   div=100 (h=0.0099): 1.131250e-03
