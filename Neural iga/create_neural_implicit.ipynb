# %%
import torch
import NeuralImplicit

# %%
relu_model = NeuralImplicit.NeuralNetwork(2,256,2,1)
total_steps = 500
steps_til_summary = total_steps/10

optim = torch.optim.Adam(lr=1e-3, params=relu_model.parameters())

# %%
relu_model.train_network(optim,total_steps,steps_til_summary)
# Out:
# Step 0, Total loss 0.244611
# Step 50, Total loss 0.000539
# Step 100, Total loss 0.000114
# Step 150, Total loss 0.000055
# Step 200, Total loss 0.000036
# Step 250, Total loss 0.000023
# Step 300, Total loss 0.000018
# Step 350, Total loss 0.000015
# Step 400, Total loss 0.000012
# Step 450, Total loss 0.000010
# Step 499, Total loss 0.000009

# %%
NeuralImplicit.plotDisctancefunction(relu_model,100,contour = True)

# %%
relu_model.save()
