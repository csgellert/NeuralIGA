# %%
import evaluation as eva
# Out:
# Larger domain: True

# %%
# Example usage - visualize MAE
filepath = "simulation_results_SIREN_circle_5_0_20260111_175131.json"
eva.visualize_results(filepath, metric='H1_error', log_scale=True)
# Out:
# Results from: simulation_results_SIREN_circle_5_0_20260111_175131.json
# Timestamp: 2026-01-11T17:51:31.203671
#
# H1_error values:
# --------------------------------------------------
#
# Order p = 1:
#   div= 10 (h=0.0909): 3.587656e-02
#   div= 20 (h=0.0476): 1.893996e-02
#   div= 50 (h=0.0196): 8.052277e-03
#   div= 80 (h=0.0123): 5.104812e-03
#   div=100 (h=0.0099): 4.020136e-03
#
# Order p = 2:
#   div= 10 (h=0.0909): 8.517393e-03
#   div= 20 (h=0.0476): 3.128469e-03
#   div= 50 (h=0.0196): 1.094172e-03
#   div= 80 (h=0.0123): 4.950654e-04
#   div=100 (h=0.0099): 8.286013e-04
#
# Order p = 3:
#   div= 10 (h=0.0909): 3.339327e-03
#   div= 20 (h=0.0476): 1.535540e-03
#   div= 50 (h=0.0196): 8.604766e-04
#   div= 80 (h=0.0123): 5.301777e-04
#   div=100 (h=0.0099): 7.003848e-04

# %%
# Example usage - visualize MAE
filepath = "simulation_results_AnalyticalDistanceCircle_20260111_185713.json"
eva.visualize_results(filepath, metric='H1_error', log_scale=True)
# Out:
# Results from: simulation_results_AnalyticalDistanceCircle_20260111_185713.json
# Timestamp: 2026-01-11T18:57:13.494035
#
# H1_error values:
# --------------------------------------------------
#
# Order p = 1:
#   div= 10 (h=0.0909): 3.586305e-02
#   div= 20 (h=0.0476): 1.891967e-02
#   div= 50 (h=0.0196): 8.008210e-03
#   div= 80 (h=0.0123): 5.077681e-03
#   div=100 (h=0.0099): 4.003810e-03
#
# Order p = 2:
#   div= 10 (h=0.0909): 8.418799e-03
#   div= 20 (h=0.0476): 2.926830e-03
#   div= 50 (h=0.0196): 8.825164e-04
#   div= 80 (h=0.0123): 4.506997e-04
#   div=100 (h=0.0099): 9.082025e-04
#
# Order p = 3:
#   div= 10 (h=0.0909): 3.239959e-03
#   div= 20 (h=0.0476): 1.152793e-03
#   div= 50 (h=0.0196): 6.514206e-04
#   div= 80 (h=0.0123): 6.076753e-04
#   div=100 (h=0.0099): 7.887448e-04

# %%
filepath = "simulation_results_SIREN_circle_1_2_20260111_205402.json"
eva.visualize_results(filepath, metric='MAE', log_scale=True)
# Out:
# Results from: simulation_results_SIREN_circle_1_2_20260111_205402.json
# Timestamp: 2026-01-11T20:54:02.779356
#
# MAE values:
# --------------------------------------------------
#
# Order p = 1:
#   div= 10 (h=0.0909): 9.408483e-04
#   div= 20 (h=0.0476): 2.874459e-04
#   div= 50 (h=0.0196): 5.659528e-05
#   div= 80 (h=0.0123): 3.164773e-05
#   div=100 (h=0.0099): 2.795754e-05
#
# Order p = 2:
#   div= 10 (h=0.0909): 1.740590e-04
#   div= 20 (h=0.0476): 6.946086e-05
#   div= 50 (h=0.0196): 2.536430e-05
#   div= 80 (h=0.0123): 2.493359e-05
#   div=100 (h=0.0099): 2.463507e-05
#
# Order p = 3:
#   div= 10 (h=0.0909): 9.536394e-05
#   div= 20 (h=0.0476): 6.286124e-05
#   div= 50 (h=0.0196): 2.533884e-05
#   div= 80 (h=0.0123): 2.449993e-05
#   div=100 (h=0.0099): 2.513881e-05

# %%
# Compare multiple simulation files
filepaths = [
    "simulation_results\\simulation_results_SIREN_circle_5_0_20260111_175131.json",
    "simulation_results\\simulation_results_AnalyticalDistanceCircle_20260111_185713.json",
    "simulation_results\\simulation_results_SIREN_circle_1_2_20260111_205402.json"
]

# Show orders 1 and 2 for all files
eva.compare_simulations(
    filepaths=filepaths,
    orders_to_show=[3],
    metric='MAE',
    log_scale=True,
    labels=['SIREN 5.0', 'Analytical', 'SIREN 1.2']  # Optional custom labels
)
# Out:
# ...
# Comparison Summary - Metric: MAE
# ...
#
# SIREN 5.0:
# --------------------------------------------------
#   Order p = 3:
#     div= 10 (h=0.0909): 4.757996e-05
#     div= 20 (h=0.0476): 1.179060e-05
#     div= 50 (h=0.0196): 6.551059e-06
#     div= 80 (h=0.0123): 3.747693e-06
#     div=100 (h=0.0099): 3.309888e-06
#
# Analytical:
# --------------------------------------------------
#   Order p = 3:
#     div= 10 (h=0.0909): 4.699986e-05
#     div= 20 (h=0.0476): 7.348872e-06
#     div= 50 (h=0.0196): 1.151338e-06
#     div= 80 (h=0.0123): 9.865633e-07
#     div=100 (h=0.0099): 2.111724e-06
#
# SIREN 1.2:
# --------------------------------------------------
#   Order p = 3:
#     div= 10 (h=0.0909): 9.536394e-05
#     div= 20 (h=0.0476): 6.286124e-05
#     div= 50 (h=0.0196): 2.533884e-05
#     div= 80 (h=0.0123): 2.449993e-05
#     div=100 (h=0.0099): 2.513881e-05
# (<Figure size 1200x700 with 1 Axes>,
# ...
